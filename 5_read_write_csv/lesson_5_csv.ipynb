# %%
import csv

# %%
def write_csv(data):
    with open('names.csv', 'a', newline = '\n') as file:
        writer = csv.writer(file)
        writer.writerow([data['name'], data['surname'], data['age']])

# %%
def writr_csv2(data):
    with open('names.csv', 'a', newline = '\n') as file:
        order = ['name', 'surname', 'age']
        writer = csv.DictWriter(file, fieldnames = order)
        writer.writerow(data)

# %%
def main():
    d = {'name': 'Petr', 'surname': 'Ivanov', 'age': 21}
    d1 = {'name': 'Ivan', 'surname': 'Ivanov', 'age': 18}
    d2 = {'name': 'Ksu', 'surname': 'Petrova', 'age': 32}
    
    l = [d, d1, d2]
    
    for i in l:
        write_csv(i)

# %%
def main():
        
    with open('cmc.csv') as file:
        fieldnames = ['name', 'url', 'price']
        reader = csv.DictReader(file, fieldnames = fieldnames)
        
        for row in reader:
            print(row)

# %%
if __name__ == '__main__':
    main()
# Out:
# OrderedDict([('name', 'Bitcoin'), ('url', 'https://coinmarketcap.com/currencies/bitcoin/'), ('price', '3416.33528246')])
# OrderedDict([('name', 'XRP'), ('url', 'https://coinmarketcap.com/currencies/ripple/'), ('price', '0.299775232653')])
# OrderedDict([('name', 'Ethereum'), ('url', 'https://coinmarketcap.com/currencies/ethereum/'), ('price', '88.4833966219')])
# OrderedDict([('name', 'Stellar'), ('url', 'https://coinmarketcap.com/currencies/stellar/'), ('price', '0.113043276315')])
# OrderedDict([('name', 'Tether'), ('url', 'https://coinmarketcap.com/currencies/tether/'), ('price', '1.01002664082')])
# OrderedDict([('name', 'Bitcoin Cash'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-cash/'), ('price', '100.238662618')])
# OrderedDict([('name', 'EOS'), ('url', 'https://coinmarketcap.com/currencies/eos/'), ('price', '1.84628048902')])
# OrderedDict([('name', 'Bitcoin SV'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-sv/'), ('price', '88.0881212378')])
# OrderedDict([('name', 'Litecoin'), ('url', 'https://coinmarketcap.com/currencies/litecoin/'), ('price', '23.7497094326')])
# OrderedDict([('name', 'TRON'), ('url', 'https://coinmarketcap.com/currencies/tron/'), ('price', '0.0133429688858')])
# OrderedDict([('name', 'Cardano'), ('url', 'https://coinmarketcap.com/currencies/cardano/'), ('price', '0.029219760821')])
# OrderedDict([('name', 'Monero'), ('url', 'https://coinmarketcap.com/currencies/monero/'), ('price', '42.7345993357')])
# OrderedDict([('name', 'NEM'), ('url', 'https://coinmarketcap.com/currencies/nem/'), ('price', '0.0694287900284')])
# OrderedDict([('name', 'IOTA'), ('url', 'https://coinmarketcap.com/currencies/iota/'), ('price', '0.224334006454')])
# OrderedDict([('name', 'Binance Coin'), ('url', 'https://coinmarketcap.com/currencies/binance-coin/'), ('price', '4.67560391343')])
# OrderedDict([('name', 'Dash'), ('url', 'https://coinmarketcap.com/currencies/dash/'), ('price', '65.4923570609')])
# OrderedDict([('name', 'Ethereum Classic'), ('url', 'https://coinmarketcap.com/currencies/ethereum-classic/'), ('price', '3.78665062364')])
# OrderedDict([('name', 'NEO'), ('url', 'https://coinmarketcap.com/currencies/neo/'), ('price', '5.8338079958')])
# OrderedDict([('name', 'Zcash'), ('url', 'https://coinmarketcap.com/currencies/zcash/'), ('price', '54.4647577371')])
# OrderedDict([('name', 'Dogecoin'), ('url', 'https://coinmarketcap.com/currencies/dogecoin/'), ('price', '0.00209352369405')])
# OrderedDict([('name', 'Maker'), ('url', 'https://coinmarketcap.com/currencies/maker/'), ('price', '318.049402053')])
# OrderedDict([('name', 'Tezos'), ('url', 'https://coinmarketcap.com/currencies/tezos/'), ('price', '0.363678489789')])
# OrderedDict([('name', 'TrueUSD'), ('url', 'https://coinmarketcap.com/currencies/trueusd/'), ('price', '1.01998634116')])
# OrderedDict([('name', 'VeChain'), ('url', 'https://coinmarketcap.com/currencies/vechain/'), ('price', '0.00372998497248')])
# OrderedDict([('name', 'Bitcoin Gold'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-gold/'), ('price', '11.4443076531')])
# OrderedDict([('name', 'USD Coin'), ('url', 'https://coinmarketcap.com/currencies/usd-coin/'), ('price', '1.02072888514')])
# OrderedDict([('name', 'OmiseGO'), ('url', 'https://coinmarketcap.com/currencies/omisego/'), ('price', '1.28872147572')])
# OrderedDict([('name', 'Paxos Standar...'), ('url', 'https://coinmarketcap.com/currencies/paxos-standard-token/'), ('price', '1.01128026151')])
# OrderedDict([('name', '0x'), ('url', 'https://coinmarketcap.com/currencies/0x/'), ('price', '0.309938158947')])
# OrderedDict([('name', 'Basic Attenti...'), ('url', 'https://coinmarketcap.com/currencies/basic-attention-token/'), ('price', '0.136473641113')])
# OrderedDict([('name', 'Waves'), ('url', 'https://coinmarketcap.com/currencies/waves/'), ('price', '1.57592032298')])
# OrderedDict([('name', 'Ontology'), ('url', 'https://coinmarketcap.com/currencies/ontology/'), ('price', '0.52708243784')])
# OrderedDict([('name', 'Qtum'), ('url', 'https://coinmarketcap.com/currencies/qtum/'), ('price', '1.67672916504')])
# OrderedDict([('name', 'Lisk'), ('url', 'https://coinmarketcap.com/currencies/lisk/'), ('price', '1.18707054273')])
# OrderedDict([('name', 'Decred'), ('url', 'https://coinmarketcap.com/currencies/decred/'), ('price', '14.6363452765')])
# OrderedDict([('name', 'Nano'), ('url', 'https://coinmarketcap.com/currencies/nano/'), ('price', '0.819564339893')])
# OrderedDict([('name', 'Bitcoin Diamond'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-diamond/'), ('price', '0.708851073517')])
# OrderedDict([('name', 'Zilliqa'), ('url', 'https://coinmarketcap.com/currencies/zilliqa/'), ('price', '0.01336583606')])
# OrderedDict([('name', 'Bytecoin'), ('url', 'https://coinmarketcap.com/currencies/bytecoin-bcn/'), ('price', '0.000569255960008')])
# OrderedDict([('name', 'BitShares'), ('url', 'https://coinmarketcap.com/currencies/bitshares/'), ('price', '0.0365820365768')])
# OrderedDict([('name', 'DigiByte'), ('url', 'https://coinmarketcap.com/currencies/digibyte/'), ('price', '0.00866323720423')])
# OrderedDict([('name', 'ICON'), ('url', 'https://coinmarketcap.com/currencies/icon/'), ('price', '0.203849125248')])
# OrderedDict([('name', 'Aurora'), ('url', 'https://coinmarketcap.com/currencies/aurora/'), ('price', '0.014150050945')])
# OrderedDict([('name', 'Aeternity'), ('url', 'https://coinmarketcap.com/currencies/aeternity/'), ('price', '0.386973810516')])
# OrderedDict([('name', 'Siacoin'), ('url', 'https://coinmarketcap.com/currencies/siacoin/'), ('price', '0.00232257518531')])
# OrderedDict([('name', 'Verge'), ('url', 'https://coinmarketcap.com/currencies/verge/'), ('price', '0.00575697471618')])
# OrderedDict([('name', 'Gemini Dollar'), ('url', 'https://coinmarketcap.com/currencies/gemini-dollar/'), ('price', '1.00767143233')])
# OrderedDict([('name', 'Factom'), ('url', 'https://coinmarketcap.com/currencies/factom/'), ('price', '9.41297687436')])
# OrderedDict([('name', 'Pundi X'), ('url', 'https://coinmarketcap.com/currencies/pundi-x/'), ('price', '0.000512623627863')])
# OrderedDict([('name', 'Chainlink'), ('url', 'https://coinmarketcap.com/currencies/chainlink/'), ('price', '0.215749587574')])
# OrderedDict([('name', 'Steem'), ('url', 'https://coinmarketcap.com/currencies/steem/'), ('price', '0.241880205461')])
# OrderedDict([('name', 'QASH'), ('url', 'https://coinmarketcap.com/currencies/qash/'), ('price', '0.206758778283')])
# OrderedDict([('name', 'Bytom'), ('url', 'https://coinmarketcap.com/currencies/bytom/'), ('price', '0.0704150973595')])
# OrderedDict([('name', 'DEX'), ('url', 'https://coinmarketcap.com/currencies/dex/'), ('price', '0.344355486818')])
# OrderedDict([('name', 'Augur'), ('url', 'https://coinmarketcap.com/currencies/augur/'), ('price', '5.95973648092')])
# OrderedDict([('name', 'MaidSafeCoin'), ('url', 'https://coinmarketcap.com/currencies/maidsafecoin/'), ('price', '0.140729830954')])
# OrderedDict([('name', 'Golem'), ('url', 'https://coinmarketcap.com/currencies/golem-network-tokens/'), ('price', '0.065961718091')])
# OrderedDict([('name', 'Stratis'), ('url', 'https://coinmarketcap.com/currencies/stratis/'), ('price', '0.631543802535')])
# OrderedDict([('name', 'Populous'), ('url', 'https://coinmarketcap.com/currencies/populous/'), ('price', '1.16528082571')])
# OrderedDict([('name', 'Revain'), ('url', 'https://coinmarketcap.com/currencies/revain/'), ('price', '0.127796342574')])
# OrderedDict([('name', 'Komodo'), ('url', 'https://coinmarketcap.com/currencies/komodo/'), ('price', '0.547822636925')])
# OrderedDict([('name', 'Holo'), ('url', 'https://coinmarketcap.com/currencies/holo/'), ('price', '0.000443612090552')])
# OrderedDict([('name', 'Decentraland'), ('url', 'https://coinmarketcap.com/currencies/decentraland/'), ('price', '0.0543605968399')])
# OrderedDict([('name', 'Cryptonex'), ('url', 'https://coinmarketcap.com/currencies/cryptonex/'), ('price', '1.01745623129')])
# OrderedDict([('name', 'Dai'), ('url', 'https://coinmarketcap.com/currencies/dai/'), ('price', '1.020819211')])
# OrderedDict([('name', 'Huobi Token'), ('url', 'https://coinmarketcap.com/currencies/huobi-token/'), ('price', '1.09012465526')])
# OrderedDict([('name', 'Electroneum'), ('url', 'https://coinmarketcap.com/currencies/electroneum/'), ('price', '0.00633875503316')])
# OrderedDict([('name', 'Ardor'), ('url', 'https://coinmarketcap.com/currencies/ardor/'), ('price', '0.0499792273498')])
# OrderedDict([('name', 'WAX'), ('url', 'https://coinmarketcap.com/currencies/wax/'), ('price', '0.0526851555858')])
# OrderedDict([('name', 'Status'), ('url', 'https://coinmarketcap.com/currencies/status/'), ('price', '0.0141995817097')])
# OrderedDict([('name', 'IOST'), ('url', 'https://coinmarketcap.com/currencies/iostoken/'), ('price', '0.00389366554908')])
# OrderedDict([('name', 'KuCoin Shares'), ('url', 'https://coinmarketcap.com/currencies/kucoin-shares/'), ('price', '0.481878758744')])
# OrderedDict([('name', 'MobileGo'), ('url', 'https://coinmarketcap.com/currencies/mobilego/'), ('price', '0.429257534685')])
# OrderedDict([('name', 'Bitcoin Private'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-private/'), ('price', '2.06029210043')])
# OrderedDict([('name', 'ODEM'), ('url', 'https://coinmarketcap.com/currencies/odem/'), ('price', '0.189131498773')])
# OrderedDict([('name', 'Nexo'), ('url', 'https://coinmarketcap.com/currencies/nexo/'), ('price', '0.0705621611487')])
# OrderedDict([('name', 'TenX'), ('url', 'https://coinmarketcap.com/currencies/tenx/'), ('price', '0.340141627136')])
# OrderedDict([('name', 'Waltonchain'), ('url', 'https://coinmarketcap.com/currencies/waltonchain/'), ('price', '0.913149099259')])
# OrderedDict([('name', 'Elastos'), ('url', 'https://coinmarketcap.com/currencies/elastos/'), ('price', '2.50140556827')])
# OrderedDict([('name', 'Linkey'), ('url', 'https://coinmarketcap.com/currencies/linkey/'), ('price', '0.711754094648')])
# OrderedDict([('name', 'STASIS EURS'), ('url', 'https://coinmarketcap.com/currencies/stasis-eurs/'), ('price', '1.1549136151')])
# OrderedDict([('name', 'Wanchain'), ('url', 'https://coinmarketcap.com/currencies/wanchain/'), ('price', '0.32679741274')])
# OrderedDict([('name', 'MOAC'), ('url', 'https://coinmarketcap.com/currencies/moac/'), ('price', '0.554469768781')])
# OrderedDict([('name', 'Polymath'), ('url', 'https://coinmarketcap.com/currencies/polymath-network/'), ('price', '0.120126618257')])
# OrderedDict([('name', 'QuarkChain'), ('url', 'https://coinmarketcap.com/currencies/quarkchain/'), ('price', '0.0426347248181')])
# OrderedDict([('name', 'Mithril'), ('url', 'https://coinmarketcap.com/currencies/mithril/'), ('price', '0.0737870519294')])
# OrderedDict([('name', 'Metaverse ETP'), ('url', 'https://coinmarketcap.com/currencies/metaverse/'), ('price', '0.607727487211')])
# OrderedDict([('name', 'THETA'), ('url', 'https://coinmarketcap.com/currencies/theta/'), ('price', '0.0461435403531')])
# OrderedDict([('name', 'PIVX'), ('url', 'https://coinmarketcap.com/currencies/pivx/'), ('price', '0.570792092727')])
# OrderedDict([('name', 'ReddCoin'), ('url', 'https://coinmarketcap.com/currencies/reddcoin/'), ('price', '0.00112262662085')])
# OrderedDict([('name', 'Ravencoin'), ('url', 'https://coinmarketcap.com/currencies/ravencoin/'), ('price', '0.0132123758381')])
# OrderedDict([('name', 'Ark'), ('url', 'https://coinmarketcap.com/currencies/ark/'), ('price', '0.2989259621')])
# OrderedDict([('name', 'Bancor'), ('url', 'https://coinmarketcap.com/currencies/bancor/'), ('price', '0.519434154203')])
# OrderedDict([('name', 'Aion'), ('url', 'https://coinmarketcap.com/currencies/aion/'), ('price', '0.117436698625')])
# OrderedDict([('name', 'Centrality'), ('url', 'https://coinmarketcap.com/currencies/centrality/'), ('price', '0.0388715883866')])
# OrderedDict([('name', 'GXChain'), ('url', 'https://coinmarketcap.com/currencies/gxchain/'), ('price', '0.510205024364')])
# OrderedDict([('name', 'Crypto.com'), ('url', 'https://coinmarketcap.com/currencies/crypto-com/'), ('price', '1.93493038145')])
# OrderedDict([('name', 'aelf'), ('url', 'https://coinmarketcap.com/currencies/aelf/'), ('price', '0.107927354435')])
# OrderedDict([('name', 'Dentacoin'), ('url', 'https://coinmarketcap.com/currencies/dentacoin/'), ('price', '8.90645211122e-05')])
# OrderedDict([('name', 'Insight Chain'), ('url', 'https://coinmarketcap.com/currencies/insight-chain/'), ('price', '0.173248612419')])
# OrderedDict([('name', 'Bitcoin'), ('url', 'https://coinmarketcap.com/currencies/bitcoin/'), ('price', '3415.95796649')])
# OrderedDict([('name', 'XRP'), ('url', 'https://coinmarketcap.com/currencies/ripple/'), ('price', '0.300183165953')])
# OrderedDict([('name', 'Ethereum'), ('url', 'https://coinmarketcap.com/currencies/ethereum/'), ('price', '88.1874576258')])
# OrderedDict([('name', 'Stellar'), ('url', 'https://coinmarketcap.com/currencies/stellar/'), ('price', '0.113098093822')])
# OrderedDict([('name', 'Tether'), ('url', 'https://coinmarketcap.com/currencies/tether/'), ('price', '1.01153447364')])
# OrderedDict([('name', 'Bitcoin Cash'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-cash/'), ('price', '100.948352825')])
# OrderedDict([('name', 'EOS'), ('url', 'https://coinmarketcap.com/currencies/eos/'), ('price', '1.84829785564')])
# OrderedDict([('name', 'Bitcoin SV'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-sv/'), ('price', '88.4739533894')])
# OrderedDict([('name', 'Litecoin'), ('url', 'https://coinmarketcap.com/currencies/litecoin/'), ('price', '23.7592994024')])
# OrderedDict([('name', 'TRON'), ('url', 'https://coinmarketcap.com/currencies/tron/'), ('price', '0.0133540975969')])
# OrderedDict([('name', 'Cardano'), ('url', 'https://coinmarketcap.com/currencies/cardano/'), ('price', '0.0292324816213')])
# OrderedDict([('name', 'Monero'), ('url', 'https://coinmarketcap.com/currencies/monero/'), ('price', '42.7840640821')])
# OrderedDict([('name', 'NEM'), ('url', 'https://coinmarketcap.com/currencies/nem/'), ('price', '0.0694850403682')])
# OrderedDict([('name', 'IOTA'), ('url', 'https://coinmarketcap.com/currencies/iota/'), ('price', '0.224401425475')])
# OrderedDict([('name', 'Binance Coin'), ('url', 'https://coinmarketcap.com/currencies/binance-coin/'), ('price', '4.69952813772')])
# OrderedDict([('name', 'Dash'), ('url', 'https://coinmarketcap.com/currencies/dash/'), ('price', '65.5011079092')])
# OrderedDict([('name', 'Ethereum Classic'), ('url', 'https://coinmarketcap.com/currencies/ethereum-classic/'), ('price', '3.78158493178')])
# OrderedDict([('name', 'NEO'), ('url', 'https://coinmarketcap.com/currencies/neo/'), ('price', '5.8474225959')])
# OrderedDict([('name', 'Zcash'), ('url', 'https://coinmarketcap.com/currencies/zcash/'), ('price', '54.5836701694')])
# OrderedDict([('name', 'Dogecoin'), ('url', 'https://coinmarketcap.com/currencies/dogecoin/'), ('price', '0.00209308015161')])
# OrderedDict([('name', 'Maker'), ('url', 'https://coinmarketcap.com/currencies/maker/'), ('price', '317.423772663')])
# OrderedDict([('name', 'Tezos'), ('url', 'https://coinmarketcap.com/currencies/tezos/'), ('price', '0.363524758387')])
# OrderedDict([('name', 'TrueUSD'), ('url', 'https://coinmarketcap.com/currencies/trueusd/'), ('price', '1.02135584414')])
# OrderedDict([('name', 'VeChain'), ('url', 'https://coinmarketcap.com/currencies/vechain/'), ('price', '0.00372265897689')])
# OrderedDict([('name', 'Bitcoin Gold'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-gold/'), ('price', '11.4100486053')])
# OrderedDict([('name', 'USD Coin'), ('url', 'https://coinmarketcap.com/currencies/usd-coin/'), ('price', '1.02245581846')])
# OrderedDict([('name', 'OmiseGO'), ('url', 'https://coinmarketcap.com/currencies/omisego/'), ('price', '1.28670988012')])
# OrderedDict([('name', 'Paxos Standar...'), ('url', 'https://coinmarketcap.com/currencies/paxos-standard-token/'), ('price', '1.01205537438')])
# OrderedDict([('name', '0x'), ('url', 'https://coinmarketcap.com/currencies/0x/'), ('price', '0.308599067215')])
# OrderedDict([('name', 'Basic Attenti...'), ('url', 'https://coinmarketcap.com/currencies/basic-attention-token/'), ('price', '0.136849912887')])
# OrderedDict([('name', 'Waves'), ('url', 'https://coinmarketcap.com/currencies/waves/'), ('price', '1.60180853367')])
# OrderedDict([('name', 'Ontology'), ('url', 'https://coinmarketcap.com/currencies/ontology/'), ('price', '0.525712795821')])
# OrderedDict([('name', 'Qtum'), ('url', 'https://coinmarketcap.com/currencies/qtum/'), ('price', '1.66889156003')])
# OrderedDict([('name', 'Lisk'), ('url', 'https://coinmarketcap.com/currencies/lisk/'), ('price', '1.18529402743')])
# OrderedDict([('name', 'Decred'), ('url', 'https://coinmarketcap.com/currencies/decred/'), ('price', '14.6450673033')])
# OrderedDict([('name', 'Nano'), ('url', 'https://coinmarketcap.com/currencies/nano/'), ('price', '0.823991191487')])
# OrderedDict([('name', 'Bitcoin Diamond'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-diamond/'), ('price', '0.709630554233')])
# OrderedDict([('name', 'Zilliqa'), ('url', 'https://coinmarketcap.com/currencies/zilliqa/'), ('price', '0.0133456538735')])
# OrderedDict([('name', 'Bytecoin'), ('url', 'https://coinmarketcap.com/currencies/bytecoin-bcn/'), ('price', '0.000569047565358')])
# OrderedDict([('name', 'BitShares'), ('url', 'https://coinmarketcap.com/currencies/bitshares/'), ('price', '0.0363407650385')])
# OrderedDict([('name', 'DigiByte'), ('url', 'https://coinmarketcap.com/currencies/digibyte/'), ('price', '0.00866015848769')])
# OrderedDict([('name', 'ICON'), ('url', 'https://coinmarketcap.com/currencies/icon/'), ('price', '0.203718433188')])
# OrderedDict([('name', 'Aurora'), ('url', 'https://coinmarketcap.com/currencies/aurora/'), ('price', '0.0141409409644')])
# OrderedDict([('name', 'Siacoin'), ('url', 'https://coinmarketcap.com/currencies/siacoin/'), ('price', '0.00235411459219')])
# OrderedDict([('name', 'Aeternity'), ('url', 'https://coinmarketcap.com/currencies/aeternity/'), ('price', '0.386807833396')])
# OrderedDict([('name', 'Verge'), ('url', 'https://coinmarketcap.com/currencies/verge/'), ('price', '0.00573975828424')])
# OrderedDict([('name', 'Factom'), ('url', 'https://coinmarketcap.com/currencies/factom/'), ('price', '9.86047875559')])
# OrderedDict([('name', 'Gemini Dollar'), ('url', 'https://coinmarketcap.com/currencies/gemini-dollar/'), ('price', '1.00933403615')])
# OrderedDict([('name', 'Pundi X'), ('url', 'https://coinmarketcap.com/currencies/pundi-x/'), ('price', '0.000519231401619')])
# OrderedDict([('name', 'Chainlink'), ('url', 'https://coinmarketcap.com/currencies/chainlink/'), ('price', '0.215437777616')])
# OrderedDict([('name', 'Steem'), ('url', 'https://coinmarketcap.com/currencies/steem/'), ('price', '0.241753544259')])
# OrderedDict([('name', 'QASH'), ('url', 'https://coinmarketcap.com/currencies/qash/'), ('price', '0.206708173178')])
# OrderedDict([('name', 'Bytom'), ('url', 'https://coinmarketcap.com/currencies/bytom/'), ('price', '0.0703593662011')])
# OrderedDict([('name', 'DEX'), ('url', 'https://coinmarketcap.com/currencies/dex/'), ('price', '0.346416381324')])
# OrderedDict([('name', 'Augur'), ('url', 'https://coinmarketcap.com/currencies/augur/'), ('price', '5.97287521236')])
# OrderedDict([('name', 'MaidSafeCoin'), ('url', 'https://coinmarketcap.com/currencies/maidsafecoin/'), ('price', '0.141283951237')])
# OrderedDict([('name', 'Golem'), ('url', 'https://coinmarketcap.com/currencies/golem-network-tokens/'), ('price', '0.0659546073638')])
# OrderedDict([('name', 'Stratis'), ('url', 'https://coinmarketcap.com/currencies/stratis/'), ('price', '0.630816671203')])
# OrderedDict([('name', 'Populous'), ('url', 'https://coinmarketcap.com/currencies/populous/'), ('price', '1.16579837139')])
# OrderedDict([('name', 'Revain'), ('url', 'https://coinmarketcap.com/currencies/revain/'), ('price', '0.128000452648')])
# OrderedDict([('name', 'Komodo'), ('url', 'https://coinmarketcap.com/currencies/komodo/'), ('price', '0.54609121632')])
# OrderedDict([('name', 'Decentraland'), ('url', 'https://coinmarketcap.com/currencies/decentraland/'), ('price', '0.0539504478914')])
# OrderedDict([('name', 'Holo'), ('url', 'https://coinmarketcap.com/currencies/holo/'), ('price', '0.000424821266303')])
# OrderedDict([('name', 'Cryptonex'), ('url', 'https://coinmarketcap.com/currencies/cryptonex/'), ('price', '1.01503314052')])
# OrderedDict([('name', 'Dai'), ('url', 'https://coinmarketcap.com/currencies/dai/'), ('price', '1.02378566637')])
# OrderedDict([('name', 'Huobi Token'), ('url', 'https://coinmarketcap.com/currencies/huobi-token/'), ('price', '1.08786228015')])
# OrderedDict([('name', 'Electroneum'), ('url', 'https://coinmarketcap.com/currencies/electroneum/'), ('price', '0.00639486438886')])
# OrderedDict([('name', 'Ardor'), ('url', 'https://coinmarketcap.com/currencies/ardor/'), ('price', '0.0500370143208')])
# OrderedDict([('name', 'Status'), ('url', 'https://coinmarketcap.com/currencies/status/'), ('price', '0.0141904221656')])
# OrderedDict([('name', 'WAX'), ('url', 'https://coinmarketcap.com/currencies/wax/'), ('price', '0.0524251327821')])
# OrderedDict([('name', 'IOST'), ('url', 'https://coinmarketcap.com/currencies/iostoken/'), ('price', '0.00387562324827')])
# OrderedDict([('name', 'KuCoin Shares'), ('url', 'https://coinmarketcap.com/currencies/kucoin-shares/'), ('price', '0.478340614232')])
# OrderedDict([('name', 'Bitcoin Private'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-private/'), ('price', '2.06745492891')])
# OrderedDict([('name', 'MobileGo'), ('url', 'https://coinmarketcap.com/currencies/mobilego/'), ('price', '0.422195246674')])
# OrderedDict([('name', 'Insight Chain'), ('url', 'https://coinmarketcap.com/currencies/insight-chain/'), ('price', '0.247167170615')])
# OrderedDict([('name', 'ODEM'), ('url', 'https://coinmarketcap.com/currencies/odem/'), ('price', '0.187874125935')])
# OrderedDict([('name', 'Nexo'), ('url', 'https://coinmarketcap.com/currencies/nexo/'), ('price', '0.0703307955841')])
# OrderedDict([('name', 'TenX'), ('url', 'https://coinmarketcap.com/currencies/tenx/'), ('price', '0.336822040542')])
# OrderedDict([('name', 'Waltonchain'), ('url', 'https://coinmarketcap.com/currencies/waltonchain/'), ('price', '0.911778294344')])
# OrderedDict([('name', 'Elastos'), ('url', 'https://coinmarketcap.com/currencies/elastos/'), ('price', '2.50448503835')])
# OrderedDict([('name', 'Linkey'), ('url', 'https://coinmarketcap.com/currencies/linkey/'), ('price', '0.709971566556')])
# OrderedDict([('name', 'STASIS EURS'), ('url', 'https://coinmarketcap.com/currencies/stasis-eurs/'), ('price', '1.15703614129')])
# OrderedDict([('name', 'Wanchain'), ('url', 'https://coinmarketcap.com/currencies/wanchain/'), ('price', '0.326610213429')])
# OrderedDict([('name', 'Polymath'), ('url', 'https://coinmarketcap.com/currencies/polymath-network/'), ('price', '0.12050064529')])
# OrderedDict([('name', 'QuarkChain'), ('url', 'https://coinmarketcap.com/currencies/quarkchain/'), ('price', '0.0430124094592')])
# OrderedDict([('name', 'MOAC'), ('url', 'https://coinmarketcap.com/currencies/moac/'), ('price', '0.545368685425')])
# OrderedDict([('name', 'Mithril'), ('url', 'https://coinmarketcap.com/currencies/mithril/'), ('price', '0.0736285613336')])
# OrderedDict([('name', 'Metaverse ETP'), ('url', 'https://coinmarketcap.com/currencies/metaverse/'), ('price', '0.604878496783')])
# OrderedDict([('name', 'PIVX'), ('url', 'https://coinmarketcap.com/currencies/pivx/'), ('price', '0.573497122491')])
# OrderedDict([('name', 'THETA'), ('url', 'https://coinmarketcap.com/currencies/theta/'), ('price', '0.0459439424914')])
# OrderedDict([('name', 'ReddCoin'), ('url', 'https://coinmarketcap.com/currencies/reddcoin/'), ('price', '0.00112377029115')])
# OrderedDict([('name', 'Ravencoin'), ('url', 'https://coinmarketcap.com/currencies/ravencoin/'), ('price', '0.0131607110978')])
# OrderedDict([('name', 'Ark'), ('url', 'https://coinmarketcap.com/currencies/ark/'), ('price', '0.299134452916')])
# OrderedDict([('name', 'Bancor'), ('url', 'https://coinmarketcap.com/currencies/bancor/'), ('price', '0.519249940937')])
# OrderedDict([('name', 'Centrality'), ('url', 'https://coinmarketcap.com/currencies/centrality/'), ('price', '0.0388665272726')])
# OrderedDict([('name', 'Aion'), ('url', 'https://coinmarketcap.com/currencies/aion/'), ('price', '0.116463536872')])
# OrderedDict([('name', 'GXChain'), ('url', 'https://coinmarketcap.com/currencies/gxchain/'), ('price', '0.509785816571')])
# OrderedDict([('name', 'Crypto.com'), ('url', 'https://coinmarketcap.com/currencies/crypto-com/'), ('price', '1.92989169181')])
# OrderedDict([('name', 'aelf'), ('url', 'https://coinmarketcap.com/currencies/aelf/'), ('price', '0.108168138545')])
# OrderedDict([('name', 'Mixin'), ('url', 'https://coinmarketcap.com/currencies/mixin/'), ('price', '64.3500640403')])
# OrderedDict([('name', 'Nxt'), ('url', 'https://coinmarketcap.com/currencies/nxt/'), ('price', '0.0284345400925')])
# OrderedDict([('name', 'Loopring'), ('url', 'https://coinmarketcap.com/currencies/loopring/'), ('price', '0.0359671659704')])
# OrderedDict([('name', 'Zcoin'), ('url', 'https://coinmarketcap.com/currencies/zcoin/'), ('price', '4.91177882482')])
# OrderedDict([('name', 'HyperCash'), ('url', 'https://coinmarketcap.com/currencies/hypercash/'), ('price', '0.649621920782')])
# OrderedDict([('name', 'Endor Protocol'), ('url', 'https://coinmarketcap.com/currencies/endor-protocol/'), ('price', '0.041150548782')])
# OrderedDict([('name', 'Dentacoin'), ('url', 'https://coinmarketcap.com/currencies/dentacoin/'), ('price', '8.60185302399e-05')])
# OrderedDict([('name', 'MonaCoin'), ('url', 'https://coinmarketcap.com/currencies/monacoin/'), ('price', '0.430345037119')])
# OrderedDict([('name', 'DigixDAO'), ('url', 'https://coinmarketcap.com/currencies/digixdao/'), ('price', '13.5493347011')])
# OrderedDict([('name', 'Loom Network'), ('url', 'https://coinmarketcap.com/currencies/loom-network/'), ('price', '0.04387162967')])
# OrderedDict([('name', 'Kin'), ('url', 'https://coinmarketcap.com/currencies/kin/'), ('price', '3.49637813809e-05')])
# OrderedDict([('name', 'Power Ledger'), ('url', 'https://coinmarketcap.com/currencies/power-ledger/'), ('price', '0.0656845810286')])
# OrderedDict([('name', 'ProximaX'), ('url', 'https://coinmarketcap.com/currencies/proximax/'), ('price', '0.00415979197938')])
# OrderedDict([('name', 'Spectre.ai Di...'), ('url', 'https://coinmarketcap.com/currencies/spectre-dividend/'), ('price', '0.308595094581')])
# OrderedDict([('name', 'Horizen'), ('url', 'https://coinmarketcap.com/currencies/zencash/'), ('price', '4.7179916463')])
# OrderedDict([('name', 'Nebulas'), ('url', 'https://coinmarketcap.com/currencies/nebulas-token/'), ('price', '0.543293275775')])
# OrderedDict([('name', 'XYO Network'), ('url', 'https://coinmarketcap.com/currencies/xyo-network/'), ('price', '0.00439617403233')])
# OrderedDict([('name', 'Digitex Futures'), ('url', 'https://coinmarketcap.com/currencies/digitex-futures/'), ('price', '0.0328722172762')])
# OrderedDict([('name', 'WaykiChain'), ('url', 'https://coinmarketcap.com/currencies/waykichain/'), ('price', '0.112548883921')])
# OrderedDict([('name', 'Byteball Bytes'), ('url', 'https://coinmarketcap.com/currencies/byteball/'), ('price', '34.3813069974')])
# OrderedDict([('name', 'Nectar'), ('url', 'https://coinmarketcap.com/currencies/nectar/'), ('price', '0.283225505085')])
# OrderedDict([('name', 'Veritaseum'), ('url', 'https://coinmarketcap.com/currencies/veritaseum/'), ('price', '11.3396594166')])
# OrderedDict([('name', 'SmartCash'), ('url', 'https://coinmarketcap.com/currencies/smartcash/'), ('price', '0.0205761934195')])
# OrderedDict([('name', 'Enjin Coin'), ('url', 'https://coinmarketcap.com/currencies/enjin-coin/'), ('price', '0.0284730308329')])
# OrderedDict([('name', 'FunFair'), ('url', 'https://coinmarketcap.com/currencies/funfair/'), ('price', '0.00386179273174')])
# OrderedDict([('name', 'Nasdacoin'), ('url', 'https://coinmarketcap.com/currencies/nasdacoin/'), ('price', '1.13383031805')])
# OrderedDict([('name', 'BHPCash'), ('url', 'https://coinmarketcap.com/currencies/bhpcash/'), ('price', '0.626033751948')])
# OrderedDict([('name', 'Credo'), ('url', 'https://coinmarketcap.com/currencies/credo/'), ('price', '0.0374829709051')])
# OrderedDict([('name', 'Smartlands'), ('url', 'https://coinmarketcap.com/currencies/smartlands/'), ('price', '4.03573335581')])
# OrderedDict([('name', 'SIRIN LABS Token'), ('url', 'https://coinmarketcap.com/currencies/sirin-labs-token/'), ('price', '0.0414681024505')])
# OrderedDict([('name', 'BOScoin'), ('url', 'https://coinmarketcap.com/currencies/boscoin/'), ('price', '0.0444638141334')])
# OrderedDict([('name', 'CyberMiles'), ('url', 'https://coinmarketcap.com/currencies/cybermiles/'), ('price', '0.024985616644')])
# OrderedDict([('name', 'Dropil'), ('url', 'https://coinmarketcap.com/currencies/dropil/'), ('price', '0.000889657964838')])
# OrderedDict([('name', 'Eidoo'), ('url', 'https://coinmarketcap.com/currencies/eidoo/'), ('price', '0.653309799122')])
# OrderedDict([('name', 'SingularityNET'), ('url', 'https://coinmarketcap.com/currencies/singularitynet/'), ('price', '0.0353965842436')])
# OrderedDict([('name', 'Enigma'), ('url', 'https://coinmarketcap.com/currencies/enigma/'), ('price', '0.254872849441')])
# OrderedDict([('name', 'Maximine Coin'), ('url', 'https://coinmarketcap.com/currencies/maximine-coin/'), ('price', '0.0111780683935')])
# OrderedDict([('name', 'Civic'), ('url', 'https://coinmarketcap.com/currencies/civic/'), ('price', '0.0529792967022')])
# OrderedDict([('name', 'Kyber Network'), ('url', 'https://coinmarketcap.com/currencies/kyber-network/'), ('price', '0.132201769268')])
# OrderedDict([('name', 'Bibox Token'), ('url', 'https://coinmarketcap.com/currencies/bibox-token/'), ('price', '0.172988710992')])
# OrderedDict([('name', 'Dent'), ('url', 'https://coinmarketcap.com/currencies/dent/'), ('price', '0.00101697366983')])
# OrderedDict([('name', 'Storj'), ('url', 'https://coinmarketcap.com/currencies/storj/'), ('price', '0.12855759663')])
# OrderedDict([('name', 'Gas'), ('url', 'https://coinmarketcap.com/currencies/gas/'), ('price', '1.72217047038')])
# OrderedDict([('name', 'SALT'), ('url', 'https://coinmarketcap.com/currencies/salt/'), ('price', '0.212279972809')])
# OrderedDict([('name', 'Fusion'), ('url', 'https://coinmarketcap.com/currencies/fusion/'), ('price', '0.573164455869')])
# OrderedDict([('name', 'Iconomi'), ('url', 'https://coinmarketcap.com/currencies/iconomi/'), ('price', '0.170893172131')])
# OrderedDict([('name', 'Dragonchain'), ('url', 'https://coinmarketcap.com/currencies/dragonchain/'), ('price', '0.0703923935299')])
# OrderedDict([('name', 'Syscoin'), ('url', 'https://coinmarketcap.com/currencies/syscoin/'), ('price', '0.0306982491112')])
# OrderedDict([('name', 'Substratum'), ('url', 'https://coinmarketcap.com/currencies/substratum/'), ('price', '0.0427881195287')])
# OrderedDict([('name', 'Bread'), ('url', 'https://coinmarketcap.com/currencies/bread/'), ('price', '0.182564352902')])
# OrderedDict([('name', 'Dynamic Tradi...'), ('url', 'https://coinmarketcap.com/currencies/dynamic-trading-rights/'), ('price', '0.0131378025506')])
# OrderedDict([('name', 'Groestlcoin'), ('url', 'https://coinmarketcap.com/currencies/groestlcoin/'), ('price', '0.219114158835')])
# OrderedDict([('name', 'Nuls'), ('url', 'https://coinmarketcap.com/currencies/nuls/'), ('price', '0.388709537903')])
# OrderedDict([('name', 'Cortex'), ('url', 'https://coinmarketcap.com/currencies/cortex/'), ('price', '0.102809823175')])
# OrderedDict([('name', 'Request Network'), ('url', 'https://coinmarketcap.com/currencies/request-network/'), ('price', '0.0210917832764')])
# OrderedDict([('name', 'Tokenomy'), ('url', 'https://coinmarketcap.com/currencies/tokenomy/'), ('price', '0.0766431643705')])
# OrderedDict([('name', 'PumaPay'), ('url', 'https://coinmarketcap.com/currencies/pumapay/'), ('price', '0.000717776310956')])
# OrderedDict([('name', 'Darico Ecosys...'), ('url', 'https://coinmarketcap.com/currencies/darcio-ecosystem-coin/'), ('price', '0.28672193763')])
# OrderedDict([('name', 'GoChain'), ('url', 'https://coinmarketcap.com/currencies/gochain/'), ('price', '0.02249991681')])
# OrderedDict([('name', 'Unobtanium'), ('url', 'https://coinmarketcap.com/currencies/unobtanium/'), ('price', '71.8727813838')])
# OrderedDict([('name', 'Genesis Vision'), ('url', 'https://coinmarketcap.com/currencies/genesis-vision/'), ('price', '3.22366695472')])
# OrderedDict([('name', 'Nexus'), ('url', 'https://coinmarketcap.com/currencies/nexus/'), ('price', '0.237128094913')])
# OrderedDict([('name', 'Peercoin'), ('url', 'https://coinmarketcap.com/currencies/peercoin/'), ('price', '0.556643231748')])
# OrderedDict([('name', 'Energi'), ('url', 'https://coinmarketcap.com/currencies/energi/'), ('price', '1.28858662036')])
# OrderedDict([('name', 'PRIZM'), ('url', 'https://coinmarketcap.com/currencies/prizm/'), ('price', '0.200945089623')])
# OrderedDict([('name', 'iExec RLC'), ('url', 'https://coinmarketcap.com/currencies/rlc/'), ('price', '0.171977288476')])
# OrderedDict([('name', 'Optimal Shelf...'), ('url', 'https://coinmarketcap.com/currencies/optimal-shelf-availability-token/'), ('price', '0.0426655332755')])
# OrderedDict([('name', 'Particl'), ('url', 'https://coinmarketcap.com/currencies/particl/'), ('price', '1.66783041987')])
# OrderedDict([('name', 'Republic Prot...'), ('url', 'https://coinmarketcap.com/currencies/republic-protocol/'), ('price', '0.0215596640149')])
# OrderedDict([('name', 'Cindicator'), ('url', 'https://coinmarketcap.com/currencies/cindicator/'), ('price', '0.00922943301903')])
# OrderedDict([('name', 'Moeda Loyalty...'), ('url', 'https://coinmarketcap.com/currencies/moeda-loyalty-points/'), ('price', '0.6733511172')])
# OrderedDict([('name', 'Telcoin'), ('url', 'https://coinmarketcap.com/currencies/telcoin/'), ('price', '0.000376654418647')])
# OrderedDict([('name', 'Odyssey'), ('url', 'https://coinmarketcap.com/currencies/odyssey/'), ('price', '0.00276280173087')])
# OrderedDict([('name', 'Quant'), ('url', 'https://coinmarketcap.com/currencies/quant/'), ('price', '1.32462357539')])
# OrderedDict([('name', 'Gnosis'), ('url', 'https://coinmarketcap.com/currencies/gnosis-gno/'), ('price', '11.7018268876')])
# OrderedDict([('name', 'Emercoin'), ('url', 'https://coinmarketcap.com/currencies/emercoin/'), ('price', '0.306436748758')])
# OrderedDict([('name', 'BnkToTheFuture'), ('url', 'https://coinmarketcap.com/currencies/bnktothefuture/'), ('price', '0.0203997148965')])
# OrderedDict([('name', 'Credits'), ('url', 'https://coinmarketcap.com/currencies/credits/'), ('price', '0.0842812780193')])
# OrderedDict([('name', 'Mainframe'), ('url', 'https://coinmarketcap.com/currencies/mainframe/'), ('price', '0.0028593532109')])
# OrderedDict([('name', 'APIS'), ('url', 'https://coinmarketcap.com/currencies/apis/'), ('price', '0.00259790017153')])
# OrderedDict([('name', 'Aragon'), ('url', 'https://coinmarketcap.com/currencies/aragon/'), ('price', '0.434828712943')])
# OrderedDict([('name', 'ETERNAL TOKEN'), ('url', 'https://coinmarketcap.com/currencies/eternal-token/'), ('price', '0.185728727664')])
# OrderedDict([('name', 'THEKEY'), ('url', 'https://coinmarketcap.com/currencies/thekey/'), ('price', '0.00249290488173')])
# OrderedDict([('name', 'Storm'), ('url', 'https://coinmarketcap.com/currencies/storm/'), ('price', '0.00270822224854')])
# OrderedDict([('name', 'Neblio'), ('url', 'https://coinmarketcap.com/currencies/neblio/'), ('price', '0.882370439808')])
# OrderedDict([('name', 'TokenPay'), ('url', 'https://coinmarketcap.com/currencies/tokenpay/'), ('price', '0.770873243741')])
# OrderedDict([('name', 'CRYPTO20'), ('url', 'https://coinmarketcap.com/currencies/c20/'), ('price', '0.299159374228')])
# OrderedDict([('name', 'Bezant'), ('url', 'https://coinmarketcap.com/currencies/bezant/'), ('price', '0.0238827624904')])
# OrderedDict([('name', 'Wagerr'), ('url', 'https://coinmarketcap.com/currencies/wagerr/'), ('price', '0.0652526045164')])
# OrderedDict([('name', 'OneRoot Network'), ('url', 'https://coinmarketcap.com/currencies/oneroot-network/'), ('price', '0.0476121467192')])
# OrderedDict([('name', 'RChain'), ('url', 'https://coinmarketcap.com/currencies/rchain/'), ('price', '0.0315327708858')])
# OrderedDict([('name', 'Santiment Net...'), ('url', 'https://coinmarketcap.com/currencies/santiment/'), ('price', '0.187963863488')])
# OrderedDict([('name', 'Vitae'), ('url', 'https://coinmarketcap.com/currencies/vitae/'), ('price', '1.10802642189')])
# OrderedDict([('name', 'STACS'), ('url', 'https://coinmarketcap.com/currencies/stacs/'), ('price', '0.0244173593178')])
# OrderedDict([('name', 'Ignis'), ('url', 'https://coinmarketcap.com/currencies/ignis/'), ('price', '0.0152393213561')])
# OrderedDict([('name', 'Neumark'), ('url', 'https://coinmarketcap.com/currencies/neumark/'), ('price', '0.251642594428')])
# OrderedDict([('name', 'Noah Coin'), ('url', 'https://coinmarketcap.com/currencies/noah-coin/'), ('price', '0.00034959678027')])
# OrderedDict([('name', 'Burst'), ('url', 'https://coinmarketcap.com/currencies/burst/'), ('price', '0.00567264180606')])
# OrderedDict([('name', 'Po.et'), ('url', 'https://coinmarketcap.com/currencies/poet/'), ('price', '0.0046621359984')])
# OrderedDict([('name', 'Gifto'), ('url', 'https://coinmarketcap.com/currencies/gifto/'), ('price', '0.0211541862823')])
# OrderedDict([('name', 'DMarket'), ('url', 'https://coinmarketcap.com/currencies/dmarket/'), ('price', '0.222986658419')])
# OrderedDict([('name', 'Everipedia'), ('url', 'https://coinmarketcap.com/currencies/everipedia/'), ('price', '0.00243696321453')])
# OrderedDict([('name', 'OST'), ('url', 'https://coinmarketcap.com/currencies/ost/'), ('price', '0.0240490745585')])
# OrderedDict([('name', 'TokenClub'), ('url', 'https://coinmarketcap.com/currencies/tokenclub/'), ('price', '0.0225713117447')])
# OrderedDict([('name', 'Streamr DATAcoin'), ('url', 'https://coinmarketcap.com/currencies/streamr-datacoin/'), ('price', '0.01603915836')])
# OrderedDict([('name', 'Bezant'), ('url', 'https://coinmarketcap.com/currencies/bezant/'), ('price', '0.0216349897257')])
# OrderedDict([('name', 'IoTeX'), ('url', 'https://coinmarketcap.com/currencies/iotex/'), ('price', '0.00705500444259')])
# OrderedDict([('name', 'Ubiq'), ('url', 'https://coinmarketcap.com/currencies/ubiq/'), ('price', '0.248131319918')])
# OrderedDict([('name', 'Cube'), ('url', 'https://coinmarketcap.com/currencies/cube/'), ('price', '0.00155663883501')])
# OrderedDict([('name', 'Matrix AI Net...'), ('url', 'https://coinmarketcap.com/currencies/matrix-ai-network/'), ('price', '0.069371095194')])
# OrderedDict([('name', 'Vertcoin'), ('url', 'https://coinmarketcap.com/currencies/vertcoin/'), ('price', '0.219473398699')])
# OrderedDict([('name', 'Einsteinium'), ('url', 'https://coinmarketcap.com/currencies/einsteinium/'), ('price', '0.0473530803881')])
# OrderedDict([('name', 'BridgeCoin'), ('url', 'https://coinmarketcap.com/currencies/bridgecoin/'), ('price', '0.380886701917')])
# OrderedDict([('name', 'Pillar'), ('url', 'https://coinmarketcap.com/currencies/pillar/'), ('price', '0.0390449937742')])
# OrderedDict([('name', 'TrueChain'), ('url', 'https://coinmarketcap.com/currencies/truechain/'), ('price', '0.213415399414')])
# OrderedDict([('name', 'Gulden'), ('url', 'https://coinmarketcap.com/currencies/gulden/'), ('price', '0.0234218933288')])
# OrderedDict([('name', 'WhiteCoin'), ('url', 'https://coinmarketcap.com/currencies/whitecoin/'), ('price', '0.0378146991925')])
# OrderedDict([('name', 'Swarm'), ('url', 'https://coinmarketcap.com/currencies/swarm-fund/'), ('price', '0.137165098031')])
# OrderedDict([('name', 'bitCNY'), ('url', 'https://coinmarketcap.com/currencies/bitcny/'), ('price', '0.148413747276')])
# OrderedDict([('name', 'TomoChain'), ('url', 'https://coinmarketcap.com/currencies/tomochain/'), ('price', '0.170900345387')])
# OrderedDict([('name', 'UTRUST'), ('url', 'https://coinmarketcap.com/currencies/utrust/'), ('price', '0.0207910672386')])
# OrderedDict([('name', 'Moss Coin'), ('url', 'https://coinmarketcap.com/currencies/moss-coin/'), ('price', '0.0414140699586')])
# OrderedDict([('name', 'Blocknet'), ('url', 'https://coinmarketcap.com/currencies/blocknet/'), ('price', '1.69943980783')])
# OrderedDict([('name', 'SaluS'), ('url', 'https://coinmarketcap.com/currencies/salus/'), ('price', '9.05094946949')])
# OrderedDict([('name', 'Nucleus Vision'), ('url', 'https://coinmarketcap.com/currencies/nucleus-vision/'), ('price', '0.0016556471576')])
# OrderedDict([('name', 'Safe Exchange...'), ('url', 'https://coinmarketcap.com/currencies/safe-exchange-coin/'), ('price', '0.00587827119145')])
# OrderedDict([('name', 'Raiden Networ...'), ('url', 'https://coinmarketcap.com/currencies/raiden-network-token/'), ('price', '0.178190940682')])
# OrderedDict([('name', 'Timicoin'), ('url', 'https://coinmarketcap.com/currencies/timicoin/'), ('price', '0.028880917266')])
# OrderedDict([('name', 'Bluzelle'), ('url', 'https://coinmarketcap.com/currencies/bluzelle/'), ('price', '0.0447963428539')])
# OrderedDict([('name', 'Skycoin'), ('url', 'https://coinmarketcap.com/currencies/skycoin/'), ('price', '0.873461472512')])
# OrderedDict([('name', 'High Performa...'), ('url', 'https://coinmarketcap.com/currencies/high-performance-blockchain/'), ('price', '0.227360839338')])
# OrderedDict([('name', 'Breezecoin'), ('url', 'https://coinmarketcap.com/currencies/breezecoin/'), ('price', '0.219204274818')])
# OrderedDict([('name', 'ARBITRAGE'), ('url', 'https://coinmarketcap.com/currencies/arbitrage/'), ('price', '1.97032941585')])
# OrderedDict([('name', 'BLOCKv'), ('url', 'https://coinmarketcap.com/currencies/blockv/'), ('price', '0.00363725564908')])
# OrderedDict([('name', 'Jibrel Network'), ('url', 'https://coinmarketcap.com/currencies/jibrel-network/'), ('price', '0.0500783194353')])
# OrderedDict([('name', 'MediBloc [ERC20]'), ('url', 'https://coinmarketcap.com/currencies/medx/'), ('price', '0.00266111682947')])
# OrderedDict([('name', 'SmartMesh'), ('url', 'https://coinmarketcap.com/currencies/smartmesh/'), ('price', '0.00591217151425')])
# OrderedDict([('name', 'Quantstamp'), ('url', 'https://coinmarketcap.com/currencies/quantstamp/'), ('price', '0.013419127613')])
# OrderedDict([('name', 'Quantum Resis...'), ('url', 'https://coinmarketcap.com/currencies/quantum-resistant-ledger/'), ('price', '0.158009357534')])
# OrderedDict([('name', 'E-Dinar Coin'), ('url', 'https://coinmarketcap.com/currencies/e-dinar-coin/'), ('price', '0.00917467044964')])
# OrderedDict([('name', 'AMO Coin'), ('url', 'https://coinmarketcap.com/currencies/amo-coin/'), ('price', '0.000906156126846')])
# OrderedDict([('name', 'Cryptaur'), ('url', 'https://coinmarketcap.com/currencies/cryptaur/'), ('price', '0.00110610517205')])
# OrderedDict([('name', 'BitBay'), ('url', 'https://coinmarketcap.com/currencies/bitbay/'), ('price', '0.00792080457573')])
# OrderedDict([('name', 'DigitalNote'), ('url', 'https://coinmarketcap.com/currencies/digitalnote/'), ('price', '0.0011446625646')])
# OrderedDict([('name', 'district0x'), ('url', 'https://coinmarketcap.com/currencies/district0x/'), ('price', '0.0131898615718')])
# OrderedDict([('name', 'Metal'), ('url', 'https://coinmarketcap.com/currencies/metal/'), ('price', '0.242313341454')])
# OrderedDict([('name', 'NavCoin'), ('url', 'https://coinmarketcap.com/currencies/nav-coin/'), ('price', '0.122373453014')])
# OrderedDict([('name', 'Zipper'), ('url', 'https://coinmarketcap.com/currencies/zip/'), ('price', '0.000476799031452')])
# OrderedDict([('name', 'Ethos'), ('url', 'https://coinmarketcap.com/currencies/ethos/'), ('price', '0.0879161779907')])
# OrderedDict([('name', 'Steem Dollars'), ('url', 'https://coinmarketcap.com/currencies/steem-dollars/'), ('price', '0.601941854825')])
# OrderedDict([('name', 'Ambrosus'), ('url', 'https://coinmarketcap.com/currencies/amber/'), ('price', '0.0528903023846')])
# OrderedDict([('name', 'NIX'), ('url', 'https://coinmarketcap.com/currencies/nix/'), ('price', '0.181472582802')])
# OrderedDict([('name', 'Own'), ('url', 'https://coinmarketcap.com/currencies/own/'), ('price', '0.104824948782')])
# OrderedDict([('name', 'Bitcoin Interest'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-interest/'), ('price', '0.41062892887')])
# OrderedDict([('name', 'Ruff'), ('url', 'https://coinmarketcap.com/currencies/ruff/'), ('price', '0.00795480314401')])
# OrderedDict([('name', 'Wowbit'), ('url', 'https://coinmarketcap.com/currencies/wowbit/'), ('price', '0.0268785145502')])
# OrderedDict([('name', 'BABB'), ('url', 'https://coinmarketcap.com/currencies/babb/'), ('price', '0.000354560673289')])
# OrderedDict([('name', 'Loki'), ('url', 'https://coinmarketcap.com/currencies/loki/'), ('price', '0.233614960662')])
# OrderedDict([('name', 'BOX Token'), ('url', 'https://coinmarketcap.com/currencies/box-token/'), ('price', '0.096934951022')])
# OrderedDict([('name', 'CasinoCoin'), ('url', 'https://coinmarketcap.com/currencies/casinocoin/'), ('price', '0.000205081162144')])
# OrderedDict([('name', 'Propy'), ('url', 'https://coinmarketcap.com/currencies/propy/'), ('price', '0.129144338553')])
# OrderedDict([('name', 'ETHLend'), ('url', 'https://coinmarketcap.com/currencies/ethlend/'), ('price', '0.00669142526884')])
# OrderedDict([('name', 'ZrCoin'), ('url', 'https://coinmarketcap.com/currencies/zrcoin/'), ('price', '1.86304447849')])
# OrderedDict([('name', 'LEOcoin'), ('url', 'https://coinmarketcap.com/currencies/leocoin/'), ('price', '0.0721286399703')])
# OrderedDict([('name', 'Time New Bank'), ('url', 'https://coinmarketcap.com/currencies/time-new-bank/'), ('price', '0.00281131877692')])
# OrderedDict([('name', 'Crypterium'), ('url', 'https://coinmarketcap.com/currencies/crypterium/'), ('price', '0.091081802145')])
# OrderedDict([('name', 'Namecoin'), ('url', 'https://coinmarketcap.com/currencies/namecoin/'), ('price', '0.490407031238')])
# OrderedDict([('name', 'Cosmo Coin'), ('url', 'https://coinmarketcap.com/currencies/cosmo-coin/'), ('price', '0.0107332982582')])
# OrderedDict([('name', 'SONM'), ('url', 'https://coinmarketcap.com/currencies/sonm/'), ('price', '0.0198647403647')])
# OrderedDict([('name', 'Sakura Bloom'), ('url', 'https://coinmarketcap.com/currencies/sakura-bloom/'), ('price', '0.00271020417902')])
# OrderedDict([('name', 'COSS'), ('url', 'https://coinmarketcap.com/currencies/coss/'), ('price', '0.0589144107403')])
# OrderedDict([('name', 'Apollo Currency'), ('url', 'https://coinmarketcap.com/currencies/apollo-currency/'), ('price', '0.000475592202119')])
# OrderedDict([('name', 'Cred'), ('url', 'https://coinmarketcap.com/currencies/libra-credit/'), ('price', '0.0149933597798')])
# OrderedDict([('name', 'MediBloc [QRC20]'), ('url', 'https://coinmarketcap.com/currencies/medibloc/'), ('price', '0.00233003937516')])
# OrderedDict([('name', 'Arcblock'), ('url', 'https://coinmarketcap.com/currencies/arcblock/'), ('price', '0.0699682523328')])
# OrderedDict([('name', 'Genaro Network'), ('url', 'https://coinmarketcap.com/currencies/genaro-network/'), ('price', '0.019116182209')])
# OrderedDict([('name', 'Modum'), ('url', 'https://coinmarketcap.com/currencies/modum/'), ('price', '0.316658383256')])
# OrderedDict([('name', 'TrueDeck'), ('url', 'https://coinmarketcap.com/currencies/truedeck/'), ('price', '0.666151579626')])
# OrderedDict([('name', 'NAGA'), ('url', 'https://coinmarketcap.com/currencies/naga/'), ('price', '0.112035287985')])
# OrderedDict([('name', 'Quanta Utilit...'), ('url', 'https://coinmarketcap.com/currencies/quanta-utility-token/'), ('price', '0.000227641159261')])
# OrderedDict([('name', 'Red Pulse Pho...'), ('url', 'https://coinmarketcap.com/currencies/red-pulse/'), ('price', '0.00802840023346')])
# OrderedDict([('name', 'AdEx'), ('url', 'https://coinmarketcap.com/currencies/adx-net/'), ('price', '0.0905366490137')])
# OrderedDict([('name', 'Rotharium'), ('url', 'https://coinmarketcap.com/currencies/rotharium/'), ('price', '1.97813010132')])
# OrderedDict([('name', 'Insolar'), ('url', 'https://coinmarketcap.com/currencies/insolar/'), ('price', '0.200547194797')])
# OrderedDict([('name', 'CyberVein'), ('url', 'https://coinmarketcap.com/currencies/cybervein/'), ('price', '0.00613583984383')])
# OrderedDict([('name', 'DATA'), ('url', 'https://coinmarketcap.com/currencies/data/'), ('price', '0.000885431493523')])
# ...
# OrderedDict([('name', 'Candy'), ('url', 'https://coinmarketcap.com/currencies/candy/'), ('price', '1.67485802149e-05')])
# OrderedDict([('name', 'Invictus Hype...'), ('url', 'https://coinmarketcap.com/currencies/invictus-hyperion-fund/'), ('price', '0.0164306837807')])
# OrderedDict([('name', 'President Trump'), ('url', 'https://coinmarketcap.com/currencies/president-trump/'), ('price', '0.00178397472388')])
# OrderedDict([('name', 'Elliot Coin'), ('url', 'https://coinmarketcap.com/currencies/elliot-coin/'), ('price', '0.00182092110953')])
# OrderedDict([('name', 'Internet of T...'), ('url', 'https://coinmarketcap.com/currencies/internet-of-things/'), ('price', '84.7297641042')])
# OrderedDict([('name', 'Bitcoin God'), ('url', 'https://coinmarketcap.com/currencies/bitcoin-god/'), ('price', '10.3249929813')])
# OrderedDict([('name', 'GameChain System'), ('url', 'https://coinmarketcap.com/currencies/gamechain/'), ('price', '0.000373757790059')])
# OrderedDict([('name', 'EPLUS Coin'), ('url', 'https://coinmarketcap.com/currencies/eplus-coin/'), ('price', '0.00444147956998')])
# OrderedDict([('name', 'XTRD'), ('url', 'https://coinmarketcap.com/currencies/xtrd/'), ('price', '0.000793353799654')])
# OrderedDict([('name', 'Noir'), ('url', 'https://coinmarketcap.com/currencies/noir/'), ('price', '0.0195425101079')])
# OrderedDict([('name', 'Cybereits'), ('url', 'https://coinmarketcap.com/currencies/cybereits/'), ('price', '0.000957060538573')])
# OrderedDict([('name', 'TerraNova'), ('url', 'https://coinmarketcap.com/currencies/terranova/'), ('price', '0.0221908852079')])
# OrderedDict([('name', 'IDOL COIN'), ('url', 'https://coinmarketcap.com/currencies/idol-coin/'), ('price', '1.08886543347e-05')])
# OrderedDict([('name', 'ContractNet'), ('url', 'https://coinmarketcap.com/currencies/contractnet/'), ('price', '0.0043644673619')])
# OrderedDict([('name', 'EmberCoin'), ('url', 'https://coinmarketcap.com/currencies/embercoin/'), ('price', '6.57663476291e-08')])
# OrderedDict([('name', 'Animecoin'), ('url', 'https://coinmarketcap.com/currencies/animecoin/'), ('price', '0.000580808866844')])
# OrderedDict([('name', 'Minex'), ('url', 'https://coinmarketcap.com/currencies/minex/'), ('price', '0.000889185710586')])
# OrderedDict([('name', 'Monero Original'), ('url', 'https://coinmarketcap.com/currencies/monero-original/'), ('price', '0.328563087892')])
# OrderedDict([('name', 'CARDbuyers'), ('url', 'https://coinmarketcap.com/currencies/cardbuyers/'), ('price', '0.00369330673945')])
# OrderedDict([('name', 'President Joh...'), ('url', 'https://coinmarketcap.com/currencies/president-johnson/'), ('price', '0.000922461141457')])
# OrderedDict([('name', 'Cubits'), ('url', 'https://coinmarketcap.com/currencies/cubits/'), ('price', '0.000580808866844')])
# OrderedDict([('name', 'SIGMAcoin'), ('url', 'https://coinmarketcap.com/currencies/sigmacoin/'), ('price', '0.00238006139896')])
# OrderedDict([('name', 'CapdaxToken'), ('url', 'https://coinmarketcap.com/currencies/capdaxtoken/'), ('price', '0.00185644789119')])
# OrderedDict([('name', 'Indicoin'), ('url', 'https://coinmarketcap.com/currencies/indicoin/'), ('price', '0.00409982729537')])
# OrderedDict([('name', 'Budbo'), ('url', 'https://coinmarketcap.com/currencies/budbo/'), ('price', '0.00274247580531')])
# OrderedDict([('name', 'Hybrid Block'), ('url', 'https://coinmarketcap.com/currencies/hybrid-block/'), ('price', '0.00208123146776')])
# OrderedDict([('name', 'Haracoin'), ('url', 'https://coinmarketcap.com/currencies/haracoin/'), ('price', '0.00676471503735')])
# OrderedDict([('name', 'Fargocoin'), ('url', 'https://coinmarketcap.com/currencies/fargocoin/'), ('price', '0.055')])
# OrderedDict([('name', 'Concierge Coin'), ('url', 'https://coinmarketcap.com/currencies/concierge-coin/'), ('price', '0.00237334303897')])
# OrderedDict([('name', 'Cobrabytes'), ('url', 'https://coinmarketcap.com/currencies/cobrabytes/'), ('price', '0.00267421924972')])
# OrderedDict([('name', 'BitNautic Token'), ('url', 'https://coinmarketcap.com/currencies/bitnautic-token/'), ('price', '0.00614974094305')])
# OrderedDict([('name', 'Vestoria'), ('url', 'https://coinmarketcap.com/currencies/vestoria/'), ('price', '9.76077063645e-07')])
# OrderedDict([('name', 'Pandemia'), ('url', 'https://coinmarketcap.com/currencies/pandemia/'), ('price', '0.000970465258672')])
# OrderedDict([('name', 'wys Token'), ('url', 'https://coinmarketcap.com/currencies/wys-token/'), ('price', '0.00352777989579')])
# OrderedDict([('name', 'DynamicCoin'), ('url', 'https://coinmarketcap.com/currencies/dynamiccoin/'), ('price', '0.000102495682384')])
# OrderedDict([('name', 'RECORD'), ('url', 'https://coinmarketcap.com/currencies/record/'), ('price', '0.00208407887514')])
# OrderedDict([('name', 'Traid'), ('url', 'https://coinmarketcap.com/currencies/traid/'), ('price', '0.00102495682384')])
# OrderedDict([('name', 'ERA'), ('url', 'https://coinmarketcap.com/currencies/blakestar/'), ('price', '0.0016399185098')])
# OrderedDict([('name', 'X12 Coin'), ('url', 'https://coinmarketcap.com/currencies/x12-coin/'), ('price', '0.006923679492')])
# OrderedDict([('name', 'Sakuracoin'), ('url', 'https://coinmarketcap.com/currencies/sakuracoin/'), ('price', '0.000273321819691')])
# OrderedDict([('name', 'SuperEdge'), ('url', 'https://coinmarketcap.com/currencies/superedge/'), ('price', '2.1450911216e-05')])
# OrderedDict([('name', 'Bastonet'), ('url', 'https://coinmarketcap.com/currencies/bastonet/'), ('price', '1.08643951425e-05')])
# OrderedDict([('name', 'Alphabit'), ('url', 'https://coinmarketcap.com/currencies/alphabitcoinfund/'), ('price', '3.95346346092')])
# OrderedDict([('name', 'BlazerCoin'), ('url', 'https://coinmarketcap.com/currencies/blazercoin/'), ('price', '0.000273321819691')])
# OrderedDict([('name', 'TWIST'), ('url', 'https://coinmarketcap.com/currencies/twist/'), ('price', '0.000341652274614')])
# OrderedDict([('name', 'Mooncoin'), ('url', 'https://coinmarketcap.com/currencies/mooncoin/'), ('price', '8.11405549135e-06')])
# OrderedDict([('name', 'Axiom'), ('url', 'https://coinmarketcap.com/currencies/axiom/'), ('price', '0.00362151411091')])
# OrderedDict([('name', 'Agrolot'), ('url', 'https://coinmarketcap.com/currencies/agrolot/'), ('price', '0.0186430661873')])
# OrderedDict([('name', 'Cropcoin'), ('url', 'https://coinmarketcap.com/currencies/cropcoin/'), ('price', '0.000136660909846')])
# OrderedDict([('name', 'Superior Coin'), ('url', 'https://coinmarketcap.com/currencies/superior-coin/'), ('price', '0.000102495682384')])
# OrderedDict([('name', 'Zealium'), ('url', 'https://coinmarketcap.com/currencies/zealium/'), ('price', '0.00510172602529')])
# OrderedDict([('name', 'Quotient'), ('url', 'https://coinmarketcap.com/currencies/quotient/'), ('price', '0.00221875852685')])
# OrderedDict([('name', 'CEDEX Coin'), ('url', 'https://coinmarketcap.com/currencies/cedex-coin/'), ('price', '0.0378164429664')])
# OrderedDict([('name', 'STEX'), ('url', 'https://coinmarketcap.com/currencies/stex/'), ('price', '0.127133874608')])
# OrderedDict([('name', 'MobilinkToken'), ('url', 'https://coinmarketcap.com/currencies/mobilinktoken/'), ('price', '0.0107275031648')])
# OrderedDict([('name', 'Centaure'), ('url', 'https://coinmarketcap.com/currencies/centaure/'), ('price', '6.83603873814e-05')])
# OrderedDict([('name', 'Labh Coin'), ('url', 'https://coinmarketcap.com/currencies/labh-coin/'), ('price', '9.92181243943e-05')])
# OrderedDict([('name', 'PlusOneCoin'), ('url', 'https://coinmarketcap.com/currencies/plusonecoin/'), ('price', '0.0265265951754')])
# OrderedDict([('name', 'Delizia'), ('url', 'https://coinmarketcap.com/currencies/delizia/'), ('price', '0.000683603873814')])
# OrderedDict([('name', 'Storjcoin X'), ('url', 'https://coinmarketcap.com/currencies/storjcoin-x/'), ('price', '0.095467765825')])
# OrderedDict([('name', 'Dutch Coin'), ('url', 'https://coinmarketcap.com/currencies/dutch-coin/'), ('price', '6.83304549228e-05')])
# OrderedDict([('name', 'MIRQ'), ('url', 'https://coinmarketcap.com/currencies/mirq/'), ('price', '6.83603873814e-05')])
# OrderedDict([('name', 'EmaratCoin'), ('url', 'https://coinmarketcap.com/currencies/emaratcoin/'), ('price', '0.0177737007192')])
# OrderedDict([('name', 'SONO'), ('url', 'https://coinmarketcap.com/currencies/altcommunity-coin/'), ('price', '0.0273321819691')])
# OrderedDict([('name', 'Magnetcoin'), ('url', 'https://coinmarketcap.com/currencies/magnetcoin/'), ('price', '0.0127436298431')])
# OrderedDict([('name', 'HondaisCoin'), ('url', 'https://coinmarketcap.com/currencies/hondaiscoin/'), ('price', '4.45386875751e-06')])
# OrderedDict([('name', 'PROUD Money'), ('url', 'https://coinmarketcap.com/currencies/proud-money/'), ('price', '0.00411642041378')])
# OrderedDict([('name', 'First Bitcoin'), ('url', 'https://coinmarketcap.com/currencies/first-bitcoin/'), ('price', '0.00249406160468')])
# OrderedDict([('name', 'Runners'), ('url', 'https://coinmarketcap.com/currencies/runners/'), ('price', '6.83304549228e-05')])
# OrderedDict([('name', 'Birds'), ('url', 'https://coinmarketcap.com/currencies/birds/'), ('price', '6.83304549228e-05')])
# OrderedDict([('name', 'RabbitCoin'), ('url', 'https://coinmarketcap.com/currencies/rabbitcoin/'), ('price', '1.10352876749e-06')])
# OrderedDict([('name', 'Civitas'), ('url', 'https://coinmarketcap.com/currencies/civitas/'), ('price', '0.0150998971779')])
# OrderedDict([('name', 'Adenz'), ('url', 'https://coinmarketcap.com/currencies/adenz/'), ('price', '0.000273441549525')])
# OrderedDict([('name', 'OmenCoin'), ('url', 'https://coinmarketcap.com/currencies/omencoin/'), ('price', '7.88395953536e-05')])
# OrderedDict([('name', 'BetaCoin'), ('url', 'https://coinmarketcap.com/currencies/betacoin/'), ('price', '0.000580808866844')])
# OrderedDict([('name', 'Crypto Improv...'), ('url', 'https://coinmarketcap.com/currencies/crypto-improvement-fund/'), ('price', '0.000307621743216')])
# OrderedDict([('name', 'BTCMoon'), ('url', 'https://coinmarketcap.com/currencies/btcmoon/'), ('price', '0.000956626368919')])
# OrderedDict([('name', 'Bitbase'), ('url', 'https://coinmarketcap.com/currencies/bitbase/'), ('price', '0.000170826137307')])
# OrderedDict([('name', 'Bubble'), ('url', 'https://coinmarketcap.com/currencies/bubble/'), ('price', '0.00242573114976')])
# OrderedDict([('name', 'GIGA'), ('url', 'https://coinmarketcap.com/currencies/giga/'), ('price', '3.41801936907e-05')])
# OrderedDict([('name', 'CottonCoin'), ('url', 'https://coinmarketcap.com/currencies/cottoncoin/'), ('price', '0.000615243486432')])
# OrderedDict([('name', 'Hyper Pay'), ('url', 'https://coinmarketcap.com/currencies/hyper-pay/'), ('price', '0.00117372910427')])
# OrderedDict([('name', 'CommunityGene...'), ('url', 'https://coinmarketcap.com/currencies/communitygeneration/'), ('price', '3.41801936907e-05')])
# OrderedDict([('name', 'EA Coin'), ('url', 'https://coinmarketcap.com/currencies/ea-coin/'), ('price', '0.00133244387099')])
# OrderedDict([('name', 'Digital Asset...'), ('url', 'https://coinmarketcap.com/currencies/digital-asset-exchange-token/'), ('price', '0.00568751461322')])
# OrderedDict([('name', 'Mero'), ('url', 'https://coinmarketcap.com/currencies/mero/'), ('price', '6.83603873814e-05')])
# OrderedDict([('name', 'YUKI'), ('url', 'https://coinmarketcap.com/currencies/yuki/'), ('price', '1.23473315923e-05')])
# OrderedDict([('name', 'BFFDoom'), ('url', 'https://coinmarketcap.com/currencies/bffdoom/'), ('price', '8.81952256592e-07')])
# OrderedDict([('name', 'Arbitracoin'), ('url', 'https://coinmarketcap.com/currencies/arbitracoin/'), ('price', '0.000785800231612')])
# OrderedDict([('name', 'OBXcoin'), ('url', 'https://coinmarketcap.com/currencies/obxcoin/'), ('price', '0.000170900968453')])
# OrderedDict([('name', 'GOLD Reward T...'), ('url', 'https://coinmarketcap.com/currencies/gold-reward-token/'), ('price', '0.00158670759931')])
# OrderedDict([('name', 'Infinipay'), ('url', 'https://coinmarketcap.com/currencies/infinipay/'), ('price', '3.75982130597e-05')])
# OrderedDict([('name', 'Excaliburcoin'), ('url', 'https://coinmarketcap.com/currencies/excaliburcoin/'), ('price', '1.10764135042e-05')])
# OrderedDict([('name', 'CoffeeCoin'), ('url', 'https://coinmarketcap.com/currencies/coffeecoin/'), ('price', '0.000246267058789')])
# OrderedDict([('name', 'AvatarCoin'), ('url', 'https://coinmarketcap.com/currencies/avatarcoin/'), ('price', '0.0276880571194')])
# OrderedDict([('name', 'Francs'), ('url', 'https://coinmarketcap.com/currencies/francs/'), ('price', '0.00249897872675')])
# OrderedDict([('name', 'Aces'), ('url', 'https://coinmarketcap.com/currencies/aces/'), ('price', '4.01126799426e-05')])
# OrderedDict([('name', 'Tellurion'), ('url', 'https://coinmarketcap.com/currencies/tellurion/'), ('price', '8.39176014185e-05')])
# OrderedDict([('name', 'Halloween Coin'), ('url', 'https://coinmarketcap.com/currencies/halloween-coin/'), ('price', '6.99174052462e-05')])
# OrderedDict([('name', 'ZenGold'), ('url', 'https://coinmarketcap.com/currencies/zengold/'), ('price', '0.00239369860109')])
# OrderedDict([('name', 'Wink'), ('url', 'https://coinmarketcap.com/currencies/wink/'), ('price', '0.000146996256923')])
# OrderedDict([('name', 'iQuant'), ('url', 'https://coinmarketcap.com/currencies/iquant/'), ('price', '0.00555755999446')])
# OrderedDict([('name', 'Ethereum Lite'), ('url', 'https://coinmarketcap.com/currencies/ethereum-lite/'), ('price', '0.0583910171991')])
# OrderedDict([('name', 'NEO GOLD'), ('url', 'https://coinmarketcap.com/currencies/neo-gold/'), ('price', '0.000676959758033')])
# OrderedDict([('name', 'PlexCoin'), ('url', 'https://coinmarketcap.com/currencies/plexcoin/'), ('price', '0.00399609147287')])
# OrderedDict([('name', 'ValueChain'), ('url', 'https://coinmarketcap.com/currencies/valuechain/'), ('price', '0.00572977744195')])
# OrderedDict([('name', 'SnipCoin'), ('url', 'https://coinmarketcap.com/currencies/snipcoin/'), ('price', '0.00036139234518')])
# OrderedDict([('name', 'SalPay'), ('url', 'https://coinmarketcap.com/currencies/salpay/'), ('price', '0.0377651227668')])
# OrderedDict([('name', 'FCoin Token'), ('url', 'https://coinmarketcap.com/currencies/fcoin-token/'), ('price', '0.0127433061577')])
# OrderedDict([('name', 'CoinEx Token'), ('url', 'https://coinmarketcap.com/currencies/coinex-token/'), ('price', '0.00434909943763')])
# OrderedDict([('name', 'Rocket Pool'), ('url', 'https://coinmarketcap.com/currencies/rocket-pool/'), ('price', '0.322253621794')])
# OrderedDict([('name', 'Luna Stars'), ('url', 'https://coinmarketcap.com/currencies/luna-stars/'), ('price', '6.97099329945e-05')])
# OrderedDict([('name', 'Pecunio'), ('url', 'https://coinmarketcap.com/currencies/pecunio/'), ('price', '0.0212847050353')])
# OrderedDict([('name', 'Obitan Chain'), ('url', 'https://coinmarketcap.com/currencies/obitan-chain/'), ('price', '9.18862761363e-07')])
# OrderedDict([('name', 'Smart Applica...'), ('url', 'https://coinmarketcap.com/currencies/smart-application-chain/'), ('price', '0.0204612945572')])
# OrderedDict([('name', 'Trendercoin'), ('url', 'https://coinmarketcap.com/currencies/trendercoin/'), ('price', '8.25546220285e-06')])
# OrderedDict([('name', 'ABCC Token'), ('url', 'https://coinmarketcap.com/currencies/abcc-token/'), ('price', '0.100680725538')])
# OrderedDict([('name', 'ALLCOIN'), ('url', 'https://coinmarketcap.com/currencies/allcoin/'), ('price', '0.0136928464606')])
# OrderedDict([('name', 'ZTCoin'), ('url', 'https://coinmarketcap.com/currencies/ztcoin/'), ('price', '0.0575929918595')])
# OrderedDict([('name', 'Dragon Token'), ('url', 'https://coinmarketcap.com/currencies/dragon-token/'), ('price', '0.735466033853')])
# OrderedDict([('name', 'APOT'), ('url', 'https://coinmarketcap.com/currencies/apot/'), ('price', '0.0204806953026')])
# OrderedDict([('name', 'Bgogo Token'), ('url', 'https://coinmarketcap.com/currencies/bgogo-token/'), ('price', '0.00109176086316')])
# OrderedDict([('name', 'Wi Coin'), ('url', 'https://coinmarketcap.com/currencies/wi-coin/'), ('price', '0.000102545644702')])
# OrderedDict([('name', 'EtherDelta Token'), ('url', 'https://coinmarketcap.com/currencies/etherdelta-token/'), ('price', '0.000239550719129')])
